# %% [markdown]
# Google API Setup
#
# Ref: https://github.com/googlemaps/google-maps-services-python

# %%
import googlemaps
from datetime import datetime
import numpy as np
import pandas as pd
import pymysql
import time
import random

keyList = [ 'Api keys go here'
          ]

# %%
conn = pymysql.connect(host='db host ip'
                       , port=3306
                       , user='user'
                       , passwd='password'
                       , db='riders')
df_user = pd.read_sql("select system_user() from dual",conn)
conn.close()
df_user.head()

# %%
#create tables
# street_address_columns = ["Street","City","State","Zipcode","Country","Latitude","Longitude"]
# station_columns = ["Station","City","State","Zipcode","Country","Latitude","Longitude"]
# neighborhood_columns = ["Neighborhood","Sublocality","Locality","County","State","Country","Latitude","Longitude"]
# premise_columns = ["Premise_Name","Latitude","Longitude"]

sql_create_street_address = "Create table if not exists riders.street_address \
(Street varchar(30), City varchar(20), State varchar(2), Zipcode numeric(5), Country varchar(3), \
Lat numeric(10,4) not null, Lon numeric(10,4) not null, \
primary key (Street, City, State, Zipcode, Country), \
foreign key (Lat, Lon) references riders.coordinates(Lat, Lon))"

sql_create_station = "Create table if not exists riders.station \
(Station varchar(30), City varchar(20), State varchar(2), Zipcode numeric(5), Country varchar(3), \
Lat numeric(10,4) not null, Lon numeric(10,4) not null, \
primary key (Station, City, State, Zipcode, Country), \
foreign key (Lat, Lon) references riders.coordinates(Lat, Lon))"

sql_create_neighborhood = "Create table if not exists riders.neighborhood \
(Neighborhood varchar(30), Sublocality varchar(30), Locality varchar(30), \
County varchar(30), State varchar(2), Country varchar(3), \
Lat numeric(10,4) not null, Lon numeric(10,4) not null, \
primary key (Neighborhood, Sublocality, Locality, County, State, Country), \
foreign key (Lat, Lon) references riders.coordinates(Lat, Lon))"

sql_create_premise = "Create table if not exists riders.premise \
(Premise_Name varchar(30), Lat numeric(10,4) not null, Lon numeric(10,4) not null, \
primary key (Premise_Name, Lat, Lon), \
foreign key (Lat, Lon) references riders.coordinates(Lat, Lon))"

conn = pymysql.connect(host='host ip address', port=3306, user='user', passwd='password', db='riders') 
cur = conn.cursor()
cur.execute(sql_create_street_address)
cur.execute(sql_create_station)
cur.execute(sql_create_neighborhood)
cur.execute(sql_create_premise)
cur.close()
conn.close()

# %%
# alter table coordinates column zip code
conn = pymysql.connect(host='host ip address', port=3306, user='user', passwd='password', db='riders')
cur = conn.cursor()
try:
    cur.execute("alter table riders.street_address add column Processed numeric(1) default 0")
except:
    pass
cur.close()
conn.close()

# %%
# alter table coordinates
conn = pymysql.connect(host='host ip address', port=3306, user='user', passwd='password', db='riders')
cur = conn.cursor()
try:
    cur.execute("alter table riders.street_address modify Zipcode varchar(5) default '00000'")
    cur.execute("alter table riders.station modify Zipcode varchar(5) default '00000'")
except:
    pass
cur.close()
conn.close()

# %%
# alter table reset primary keys
conn = pymysql.connect(host='host ip address', port=3306, user='user', passwd='password', db='riders')
cur = conn.cursor()
try:
    cur.execute("alter table riders.street_address drop primary key")
    cur.execute("alter table riders.street_address add primary key \
    (Street, City, State, Zipcode, Country, Lat, Lon)")
    cur.execute("alter table riders.station drop primary key")
    cur.execute("alter table riders.station add primary key \
    (Station, City, State, Zipcode, Country, Lat, Lon)")
    cur.execute("alter table riders.neighborhood drop primary key")
    cur.execute("alter table riders.neighborhood add primary key \
    (Neighborhood, Sublocality, Locality, County, State, Country, Lat, Lon)")
except:
    pass
cur.close()
conn.close()

# %%
def parseAndStoreStreetAddress(address, latitude, longitude):
    global street_address_columns
    global df_street_address
    # print(address)
    street_address_list = address.split(",")
    # strip white spaces in beginning and end of string in the list
    for i in range(0,len(street_address_list)):
        street_address_list[i] = street_address_list[i].strip()
    #state and zip are given as one string
    #split state and zip code and add it back to the list in place of state zip code string
    state_zipcode_list = street_address_list[2].split(" ")
#     print(state_zipcode_list)
    street_address_list.insert(2,state_zipcode_list[0].strip())
    street_address_list[3] = state_zipcode_list[1].strip()
    #add longitude and latitude to the list to store in dataframe later
    street_address_list.append(latitude)
    street_address_list.append(longitude)
    df = pd.DataFrame([street_address_list], columns=street_address_columns)
    df_street_address = df_street_address.append(df,ignore_index=True)

# %%
def parseAndStoreStation(address, latitude, longitude):
    global station_columns
    global df_station
    #print(address)
    station_list = address.split(",")
    # strip white spaces in beginning and end of string in the list
    for i in range(0,len(station_list)):
        station_list[i] = station_list[i].strip()
    #state and zip are given as one string
    #split state and zip code and add it back to the list in place of state zip code string
    state_zipcode_list = station_list[2].split(" ")
#     print(state_zipcode_list)
    station_list.insert(2,state_zipcode_list[0].strip())
    station_list[3] = state_zipcode_list[1].strip()
    #add longitude and latitude to the list to store in dataframe later
    station_list.append(latitude)
    station_list.append(longitude)
    df = pd.DataFrame([station_list], columns=station_columns)
    df_station = df_station.append(df,ignore_index=True)

# %%
def parseAndStoreNeighborhood(address, latitude, longitude):
    global neighborhood_columns
    global df_neighborhood

    neighborhood=''
    sublocality=''
    locality=''
    county=''
    state=''
    country=''
    for i in range(0,len(address)):
        address_types = address[i]
#         print('address_type:', address_types)
        if 'sublocality' in address_types['types']:
            sublocality = address_types['short_name'].strip()
        elif 'locality' in address_types['types']:
            locality = address_types['short_name'].strip()
        elif 'administrative_area_level_2' in address_types['types']:
            county = address_types['short_name'].strip()
        elif 'administrative_area_level_1' in address_types['types']:
            state = address_types['short_name'].strip()
        elif 'neighborhood' in address_types['types']:
            neighborhood = address_types['short_name'].strip()
        elif 'country' in address_types['types']:
            country = address_types['short_name'].strip()
    neighborhood_list = [neighborhood, sublocality, locality,county,state,country,latitude,longitude]
#     print(neighborhood_list)
    df = pd.DataFrame([neighborhood_list], columns=neighborhood_columns)
    df_neighborhood = df_neighborhood.append(df,ignore_index=True)

# %%
def parseAndStorePremise(address,latitude,longitude):
    global df_establishment 
    global establishment_columns
    for i in range(0,len(address)):
        print(address)
        if 'premise' in address['types']:
            premise = address['short_name'].strip()
    premise_list = [premise, latitude, longitude]
    df = pd.DataFrame(premise_list, columns=premise_columns)
    print(df)
    df_premise = df_premise.append(df, ignore_index=True)

# %%
def findAndStoreAddress(result, latitude, longitude):
    for i in range(0,len(result)):
        address = result[i]
#         print( 'Address-Type: ', address['types'])
        if 'street_address' in address['types']:
            parseAndStoreStreetAddress(address['formatted_address'],latitude,longitude)
        elif 'bus_station' in address['types'] or 'transit_station' in address['types']:
            parseAndStoreStation(address['formatted_address'],latitude,longitude)
        elif 'neighborhood' in address['types']:
            parseAndStoreNeighborhood(address['address_components'],latitude,longitude)
#         elif 'premise' in address['types']:
#             parseAndStorePremise(address['address_components'],latitude,longitude)

# %%
#insert data intodatabase

# street_address_columns = ["Street","City","State","Zipcode","Country","Latitude","Longitude"]
# station_columns = ["Station","City","State","Zipcode","Country","Latitude","Longitude"]
# neighborhood_columns = ["Neighborhood","Sublocality","Locality","County","State","Country","Latitude","Longitude"]
# premise_columns = ["Premise_Name","Latitude","Longitude"]

def insertData(df_coordinates):
    global df_street_address
    global df_station
    global df_neighborhood
    global df_premise
    
    insert_address = "insert ignore into riders.street_address \
    (Street, City, State, Zipcode, Country, Lat, Lon) value(%s, %s, %s, %s, %s, %s, %s)"

    insert_station = "insert ignore into riders.station \
    (Station, City, State, Zipcode, Country, Lat, Lon) value(%s, %s, %s, %s, %s, %s, %s)"

    insert_neighborhood = "insert ignore into riders.neighborhood \
    (Neighborhood, Sublocality, Locality, County, State, Country, Lat, Lon) \
    value(%s, %s, %s, %s, %s, %s, %s, %s)"

    insert_premise = "insert ignore into riders.premise \
    (Premise_Name, Lat, Lon) value(%s, %s, %s)"
    
    update_coordinates = "update riders.coordinates c set processed = 1 \
    where c.lat = %s and c.lon = %s"
    
    conn = pymysql.connect(host='192.168.1.95', port=3306, user='msds6210team', passwd='msds6210uber', db='riders')
    cur = conn.cursor()
#     try:
    cur.executemany(insert_address, df_street_address.values.tolist())
    cur.executemany(insert_station, df_station.values.tolist())
    cur.executemany(insert_neighborhood, df_neighborhood.values.tolist())
    cur.executemany(insert_premise, df_premise.values.tolist())
    #     print(df_coordinates.values.tolist())
    cur.executemany(update_coordinates, df_coordinates.values.tolist())
#     except:
#         pass
    cur.close()
    conn.commit()
    conn.close()

# %%
def getCoordinates():
    conn = pymysql.connect(host='host ip address'
                           , port=3306
                           , user='user'
                           , passwd='password'
                           , db='riders')
    sql_select = "select distinct c.lat, c.lon from coordinates c \
    where c.processed = 0 limit 30"

    df = pd.read_sql(sql_select,conn)
    conn.close()
#     print(df.head)
    return df

# %%
def emptyDataFrames():
    global df_street_address
    global df_station
    global df_neighborhood
    global df_premise
    
    df_street_address.drop(df_street_address.index, inplace=True)
    df_station.drop(df_station.index, inplace=True)
    df_neighborhood.drop(df_neighborhood.index, inplace=True)
    df_premise.drop(df_premise.index, inplace=True)

# %%
def loadDataFrames(df_coordinates):
    global keyList
    gkey = keyList[random.randint(0,2)]
    gmaps = googlemaps.Client(key=gkey)
    print('gmaps key being used: ', gkey)
    for index, row in df_coordinates.iterrows():
        lat, lon = row
        try:
            search_result = gmaps.reverse_geocode((lat,lon ))
#             print(search_result)
        except:
            gkey = keyList[random.randint(0,2)]
            gmaps = googlemaps.Client(key=gkey)
            pass
        try:
            findAndStoreAddress(search_result, lat, lon)
        except:
            pass
        break

# %%
# set up empty data frames to store parsed data type
street_address_columns = ["Street","City","State","Zipcode","Country","Latitude","Longitude"]
station_columns = ["Station","City","State","Zipcode","Country","Latitude","Longitude"]
neighborhood_columns = ["Neighborhood","Sublocality","Locality","County","State","Country","Latitude","Longitude"]
premise_columns = ["Premise_Name","Latitude","Longitude"]
df_street_address = pd.DataFrame([],columns=street_address_columns)
df_street_address = df_street_address.fillna(0)
df_station = pd.DataFrame([],columns=station_columns)
df_station = df_station.fillna(0)
df_neighborhood = pd.DataFrame([],columns=neighborhood_columns)
df_neighborhood = df_neighborhood.fillna(0)
df_premise = pd.DataFrame([],columns=premise_columns)
df_premise = df_premise.fillna(0)

# %%
count = 0
while True:
    df_coordinates = getCoordinates()
    loadDataFrames(df_coordinates)
    insertData(df_coordinates)
    emptyDataFrames()
    count += 1
    print('loaded data for ', count, ' times')
    sleeptime = random.uniform(60,150)
    
    print('Will wait ', sleeptime/60, ' before running process again')
    time.sleep(sleeptime)
# Out:
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py:166: Warning: (1265, "Data truncated for column 'Country' at row 1")
#   result = self._query(query)
# loaded data for  1  times
# Will wait  2.4185579268702497  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  2  times
# Will wait  1.861288786903197  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  3  times
# Will wait  2.225652272777458  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  4  times
# Will wait  1.105145170201315  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  5  times
# Will wait  1.6570879427009544  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  6  times
# Will wait  2.44436963336839  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  7  times
# Will wait  2.144894155860727  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  8  times
# Will wait  1.316196864578295  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  9  times
# Will wait  2.0356164724639165  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  10  times
# Will wait  2.4220305639820388  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  11  times
# Will wait  1.2594342086537502  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  12  times
# Will wait  1.1631033163343907  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  13  times
# Will wait  1.2269436880521531  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  14  times
# Will wait  2.3193180585084434  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  15  times
# Will wait  1.5510217591068098  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  16  times
# Will wait  1.6963377883879276  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  17  times
# Will wait  2.4140697560718727  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  18  times
# Will wait  1.173339574276539  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  19  times
# Will wait  2.0924281133792397  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  20  times
# Will wait  1.9217365229089667  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  21  times
# Will wait  1.6308849722179113  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  22  times
# Will wait  2.3912980361625555  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  23  times
# Will wait  1.1270952727654708  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  24  times
# Will wait  1.1063134440627758  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  25  times
# Will wait  1.8985647151590106  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  26  times
# Will wait  2.4184907750821663  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  27  times
# Will wait  1.2637277132610027  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  28  times
# Will wait  2.1383361951861426  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  29  times
# Will wait  1.8037135032427878  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  30  times
# Will wait  1.7808054400889257  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  31  times
# Will wait  2.1093050265062194  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  32  times
# Will wait  1.1043941127910828  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  33  times
# Will wait  1.544505128121967  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  34  times
# Will wait  2.417711927120657  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  35  times
# Will wait  1.742897204417847  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  36  times
# Will wait  2.2990796091061743  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  37  times
# Will wait  1.5672186908910504  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  38  times
# Will wait  1.8927880572399463  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  39  times
# Will wait  1.777336564525882  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  40  times
# Will wait  1.903557080275806  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# C:\Anaconda3\lib\site-packages\pymysql\cursors.py:166: Warning: (1265, "Data truncated for column 'Station' at row 1")
#   result = self._query(query)
# loaded data for  41  times
# Will wait  1.0126638007205975  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  42  times
# Will wait  2.190902892919931  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  43  times
# Will wait  1.9984122295771405  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  44  times
# Will wait  1.5297672930385846  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  45  times
# Will wait  2.446014128784492  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  46  times
# Will wait  1.6833260212906207  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  47  times
# Will wait  1.7364734835638511  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  48  times
# Will wait  1.8820163604769435  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  49  times
# Will wait  1.9029793898101217  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  50  times
# Will wait  1.413431575668287  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  51  times
# Will wait  1.5112515750783768  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  52  times
# Will wait  1.2911987867639776  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  53  times
# Will wait  2.259365752884844  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  54  times
# Will wait  2.353578706884619  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  55  times
# Will wait  1.3957633724476937  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for
before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1614  times
# Will wait  1.1117962653062032  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1615  times
# Will wait  2.455277791164116  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1616  times
# Will wait  1.529894230985402  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1617  times
# Will wait  1.0784114158361944  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1618  times
# Will wait  1.462663731250535  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1619  times
# Will wait  1.6951835440731755  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1620  times
# Will wait  1.77555064500106  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1621  times
# Will wait  1.674671644333682  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1622  times
# Will wait  1.6624963224832248  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1623  times
# Will wait  1.6878476314076787  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1624  times
# Will wait  2.32578939693128  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1625  times
# Will wait  1.7783136209037116  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1626  times
# Will wait  1.580292877588098  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1627  times
# Will wait  1.85478799345193  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1628  times
# Will wait  1.9300673785802482  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1629  times
# Will wait  1.7798733637175086  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1630  times
# Will wait  2.39885594979089  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1631  times
# Will wait  1.9851329256489085  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1632  times
# Will wait  2.3006760719454813  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1633  times
# Will wait  1.4310334058018195  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1634  times
# Will wait  2.220112858460138  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1635  times
# Will wait  1.6662967394217867  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1636  times
# Will wait  2.118153626113574  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1637  times
# Will wait  1.4756713857079033  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1638  times
# Will wait  1.8302790264026598  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1639  times
# Will wait  2.3605382831299693  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1640  times
# Will wait  1.126265511251579  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1641  times
# Will wait  2.444267412434252  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1642  times
# Will wait  1.1124516223385004  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1643  times
# Will wait  2.12500986526489  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1644  times
# Will wait  2.2259210907692295  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1645  times
# Will wait  2.2696624679818456  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1646  times
# Will wait  1.7255474170480583  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1647  times
# Will wait  1.0238881392707435  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1648  times
# Will wait  1.073990115061101  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1649  times
# Will wait  1.9400131614498368  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1650  times
# Will wait  1.2388497875012485  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1651  times
# Will wait  1.9715253177064251  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1652  times
# Will wait  1.7582194548058783  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1653  times
# Will wait  1.1233780448448016  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1654  times
# Will wait  1.3399046690219192  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1655  times
# Will wait  1.2987892638283582  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1656  times
# Will wait  2.3413655356395435  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1657  times
# Will wait  1.2402894803754407  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1658  times
# Will wait  1.0350817976782636  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1659  times
# Will wait  2.1619759299435994  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1660  times
# Will wait  2.32500244937109  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1661  times
# Will wait  1.9455614009853923  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1662  times
# Will wait  1.6114777855463618  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1663  times
# Will wait  1.557564010169905  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1664  times
# Will wait  1.7488397350096838  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1665  times
# Will wait  1.9004693884954316  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1666  times
# Will wait  1.7979273931559796  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1667  times
# Will wait  1.4029728306852287  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1668  times
# Will wait  2.403519154027533  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1669  times
# Will wait  1.2309459278603219  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1670  times
# Will wait  2.1494033731950375  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1671  times
# Will wait  1.3111422733884337  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1672  times
# Will wait  2.0362749324349645  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1673  times
# Will wait  1.0311746325647067  before running process again
# gmaps key being used:  AIzaSyCXNDeJNDla9FmStA7LG0mWShpGpk5eDFc
# loaded data for  1674  times
# Will wait  1.36320748827633  before running process again
# gmaps key being used:  AIzaSyCFRldmw9QOOOhCsfCsl8S5B0oLhRN1HxY
# loaded data for  1675  times
# Will wait  1.4219942027699815  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1676  times
# Will wait  1.695596874601776  before running process again
# gmaps key being used:  AIzaSyBGJlWlxZEnJ2yUape3AjqmNyo5--h6xtI
# loaded data for  1677  times
# Will wait  2.16882271492321  before running process again

# %%
print('Street address data frame')
df_street_address.head()

# %%
print('Station data frame')
df_station.head()

# %%
print('Neighborhood data frame')
df_neighborhood.head()

# %%
print('Premise data frame')
df_premise.head()
